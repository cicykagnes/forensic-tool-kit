# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1fc52537-68c3-452e-bb1c-2c9b6e8d3928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fc52537-68c3-452e-bb1c-2c9b6e8d3928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"cicykagnes","key":"4eabc237e56ff43f9ac231fa5c203f53"}'}

# %%
# !pip install -q kaggle

# %%
# create a folder named kaggle
# !mkdir -p ~/.kaggle
#copy kaggle.json into kaggle folder
# !cp kaggle.json ~/.kaggle/
#change permission so you  can only read-write
'chmod 600 /root/.kaggle/kaggle.json'
# Out:
# 'chmod 600 /root/.kaggle/kaggle.json'

# %%
# !kaggle datasets download -d arbazkhan971/cuhk-face-sketch-database-cufs
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading cuhk-face-sketch-database-cufs.zip to /content
#  91% 103M/113M [00:00<00:00, 157MB/s]
# 100% 113M/113M [00:00<00:00, 166MB/s]

# %%
# !ls
# Out:
# cuhk-face-sketch-database-cufs.zip  kaggle.json  sample_data

# %%
# !unzip cuhk-face-sketch-database-cufs.zip

# %%
# !ls
# Out:
# cropped_sketch			    original_sketch  photos	  sketches
# cuhk-face-sketch-database-cufs.zip  photo	     sample_data  sketch_points
# kaggle.json			    photo_points     sketch

# %%
import numpy as np
import tensorflow as tf
import keras 
from keras.preprocessing.image import img_to_array
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm 
import os
import re

# %%
# to get the files in proper order
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)


# defining the size of image 
SIZE = 256

image_path = 'photos'
img_array = []

sketch_path = 'sketches'
sketch_array = []

image_file = sorted_alphanumeric(os.listdir(image_path))
sketch_file = sorted_alphanumeric(os.listdir(sketch_path))


for i in tqdm(image_file):
    image = cv2.imread(image_path + '/' + i,1)
    
    # as opencv load image in bgr format converting it to rgb
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # resizing images 
    image = cv2.resize(image, (SIZE, SIZE))
    
    # normalizing image 
    image = (image.astype('float32') - 127.5) / 127.5
    
    #appending normal normal image    
    img_array.append(img_to_array(image))
    # Image Augmentation
    '''
    # horizontal flip 
    img1 = cv2.flip(image,1)
    img_array.append(img_to_array(img1))
     #vertical flip 
    img2 = cv2.flip(image,-1)
    img_array.append(img_to_array(img2))
     #vertical flip 
    img3 = cv2.flip(image,-1)
    # horizontal flip
    img3 = cv2.flip(img3,1)
    img_array.append(img_to_array(img3))
    # rotate clockwise 
    img4 = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
    img_array.append(img_to_array(img4))
    # flip rotated image 
    img5 = cv2.flip(img4,1)
    img_array.append(img_to_array(img5))
     # rotate anti clockwise 
    img6 = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)
    img_array.append(img_to_array(img6))
    # flip rotated image 
    img7 = cv2.flip(img6,1)
    img_array.append(img_to_array(img7))
  
    '''
for i in tqdm(sketch_file):
    image = cv2.imread(sketch_path + '/' + i,1)
    
    # as opencv load image in bgr format converting it to rgb
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # resizing images 
    image = cv2.resize(image, (SIZE, SIZE))
    
    # normalizing image 
    image = (image.astype('float32') - 127.5) / 127.5
    # appending normal sketch image
    sketch_array.append(img_to_array(image))
    '''
    #Image Augmentation
    # horizontal flip 
    img1 = cv2.flip(image,1)
    sketch_array.append(img_to_array(img1))
     #vertical flip 
    img2 = cv2.flip(image,-1)
    sketch_array.append(img_to_array(img2))
     #vertical flip 
    img3 = cv2.flip(image,-1)
    # horizontal flip
    img3 = cv2.flip(img3,1)
    sketch_array.append(img_to_array(img3))
    # rotate clockwise 
    img4 = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
    sketch_array.append(img_to_array(img4))
    # flip rotated image 
    img5 = cv2.flip(img4,1)
    sketch_array.append(img_to_array(img5))
     # rotate anti clockwise 
    img6 = cv2.rotate(image, cv2.ROTATE_90_COUNTERCLOCKWISE)
    sketch_array.append(img_to_array(img6))
    # flip rotated image 
    img7 = cv2.flip(img6,1)
    sketch_array.append(img_to_array(img7))
    
    '''
# Out:
# 100%|██████████| 188/188 [00:00<00:00, 596.88it/s]
# 100%|██████████| 188/188 [00:00<00:00, 657.74it/s]

# %%
print("Total number of sketch images:",len(sketch_array))
print("Total number of images:",len(img_array))
# Out:
# Total number of sketch images: 188
# Total number of images: 188

# %%
# defining function to plot images pair
def plot_images(image, sketches):
    plt.figure(figsize=(7,7))
    plt.subplot(1,2,1)
    plt.title('Image', color = 'black', fontsize = 20)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.title('Sketches ', color = 'black', fontsize = 20)
    plt.imshow(sketches)
   
    plt.show()

# %%
ls = [i for i in range(0,65,8)]
for i in ls:
    plot_images(img_array[i],sketch_array[i])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_sketch_image = sketch_array[:160]
train_image = img_array[:160]
test_sketch_image = sketch_array[160:]
test_image = img_array[160:]
# reshaping
train_sketch_image = np.reshape(train_sketch_image,(len(train_sketch_image),SIZE,SIZE,3))
train_image = np.reshape(train_image, (len(train_image),SIZE,SIZE,3))
print('Train color image shape:',train_image.shape)
print('Train sketch shape:',train_sketch_image.shape)
test_sketch_image = np.reshape(test_sketch_image,(len(test_sketch_image),SIZE,SIZE,3))
test_image = np.reshape(test_image, (len(test_image),SIZE,SIZE,3))
print('Test color image shape',test_image.shape)
print('Test sketch shape:',test_sketch_image.shape)
# Out:
# Train color image shape: (160, 256, 256, 3)
# Train sketch shape: (160, 256, 256, 3)
# Test color image shape (28, 256, 256, 3)
# Test sketch shape: (28, 256, 256, 3)

# %%
'''
# normalize pixel values
train_sketch_image = (train_sketch_image.astype('float32')- 127.5) / 127.5
train_image = (train_sketch_image.astype('float32')- 127.5) / 127.5
test_sketch_image = (train_sketch_image.astype('float32')- 127.5) / 127.5
test_image = (train_sketch_image.astype('float32')- 127.5) / 127.5

'''
# Out:
# "\n# normalize pixel values\ntrain_sketch_image = (train_sketch_image.astype('float32')- 127.5) / 127.5\ntrain_image = (train_sketch_image.astype('float32')- 127.5) / 127.5\ntest_sketch_image = (train_sketch_image.astype('float32')- 127.5) / 127.5\ntest_image = (train_sketch_image.astype('float32')- 127.5) / 127.5\n\n"

# %%
type(train_image)
# Out:
# numpy.ndarray

# %%
# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
    # unpack dataset
    trainA, trainB = dataset

    # choose random instances
    ix = np.random.randint(0, trainA.shape[0], n_samples)
    
    # retrieve selected images
    X1, X2 = trainA[ix], trainB[ix]
    
    # generate 'real' class labels (1)
    y = np.ones((n_samples, patch_shape, patch_shape, 1))
    
    return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
    # generate fake instance
    X = g_model.predict(samples)
    
    # create 'fake' class labels (0)
    y = np.zeros((len(X), patch_shape, patch_shape, 1))
    
    return X, y


# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, d_model, dataset, n_samples=3):
    
    # select a sample of input images
    [X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
    # generate a batch of fake samples
    X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
    # scale all pixels from [-1,1] to [0,1]
    X_realA = (X_realA + 1) / 2.0
    X_realB = (X_realB + 1) / 2.0
    X_fakeB = (X_fakeB + 1) / 2.0
    # plot real source images
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + i)
        plt.axis('off')
        plt.imshow(X_realA[i])

    # plot generated target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples + i)
        plt.axis('off')
        plt.imshow(X_fakeB[i])
    # plot real target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples*2 + i)
        plt.axis('off')
        plt.imshow(X_realB[i])
    
    # save the generator model
    g_model.save('g_model.h5')
    
    # save the discriminator model
    d_model.save('d_model.h5')
    
    print('>Saved:  g_model & d_model')

# %%
pip install git+https://www.github.com/keras-team/keras-contrib.git
# Out:
# Collecting git+https://www.github.com/keras-team/keras-contrib.git
#   Cloning https://www.github.com/keras-team/keras-contrib.git to /tmp/pip-req-build-e05123cn
#   Running command git clone -q https://www.github.com/keras-team/keras-contrib.git /tmp/pip-req-build-e05123cn
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from keras-contrib==2.0.8) (2.7.0)
# Building wheels for collected packages: keras-contrib
#   Building wheel for keras-contrib (setup.py) ... done
#   Created wheel for keras-contrib: filename=keras_contrib-2.0.8-py3-none-any.whl size=101077 sha256=71d47e9096534e211d56f09fa12ea909670bd04a40109da96ea84fcf0b69124b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oxk31_cq/wheels/bb/1f/f2/b57495012683b6b20bbae94a3915ec79753111452d79886abc
# Successfully built keras-contrib
# Installing collected packages: keras-contrib
# Successfully installed keras-contrib-2.0.8

# %%
from __future__ import print_function, division

from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam

from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img

from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import datetime
import natsort
import scipy
import sys
import os
import cv2

# %%
def generator(img_shape):
    def conv2d(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d
    
    def deconv2d(layer_in, skip_in, n_filter, dropout=0.5):
        d = UpSampling2D(size=2)(layer_in)
        d = Conv2D(n_filter, kernel_size=4, strides=1, padding='same', activation='relu')(d)
        if dropout:
            d = Dropout(dropout)(d)
        d = InstanceNormalization()(d)
        d = Concatenate()([d, skip_in])
        return d
    
    # Input Layer
    in_img = Input(shape=img_shape)
    
    # Downsampling
    d1 = conv2d(in_img, 64, norm=False)
    d2 = conv2d(d1, 128)
    d3 = conv2d(d2, 256)
    d4 = conv2d(d3, 512)
    d5 = conv2d(d4, 512)
    d6 = conv2d(d5, 512)
    d7 = conv2d(d6, 512)
    
    # Upsampling
    u1 = deconv2d(d7, d6, 512)
    u2 = deconv2d(u1, d5, 512)
    u3 = deconv2d(u2, d4, 512)
    u4 = deconv2d(u3, d3, 256, dropout=0)
    u5 = deconv2d(u4, d2, 128, dropout=0)
    u6 = deconv2d(u5, d1, 64, dropout=0)
    u7 = UpSampling2D(size=2)(u6)
    
    out_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh')(u7)
    
    return Model(in_img, out_img, name='generator')

def discriminator(img_shape):
    def d_layer(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d
    
    in_src_img = Input(shape=img_shape)
    in_target_img = Input(shape=img_shape)
    
    merged = Concatenate()([in_src_img, in_target_img])
    
    d1 = d_layer(merged, 64, norm=False)
    d2 = d_layer(d1, 128)
    d3 = d_layer(d1, 256)
    d4 = d_layer(d1, 512)

    out = Conv2D(1, kernel_size=4, strides=1, padding='same')(d4)
    
    return Model([in_src_img, in_target_img], out, name='discriminator')


def GAN(g_model, d_model, img_shape):
    d_model.trainable = False
    in_img = Input(shape=img_shape)
    gen_out = g_model(in_img)
    dis_out = d_model([in_img, gen_out])
    model = Model(in_img, [dis_out, gen_out], name='GAN')
    return model

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import mean_absolute_error

def pixel_loss(y_true, y_pred):
    return K.mean(K.abs(y_true - y_pred))

def contextual_loss (y_true, y_pred):
    a = tf.image.rgb_to_grayscale(tf.slice(
                                y_pred, 
                                [0,0,0,0], 
                                [16, 256, 256, 3]))
    
    b = tf.image.rgb_to_grayscale(tf.slice(
                                y_true, 
                                [0,0,0,0], 
                                [16, 256, 256, 3]))
    
    y_pred = tf.divide(tf.add(tf.reshape(a, [tf.shape(a)[0], -1]), 1), 2)
    y_true = tf.divide(tf.add(tf.reshape(b, [tf.shape(b)[0], -1]), 1), 2)
    
#     tf.assert_rank(y_true,2)
#     tf.assert_rank(y_pred,2)
    
    p_shape = tf.shape(y_true)
    q_shape = tf.shape(y_pred)
#     tf.assert_equal(p_shape, q_shape)
    
    # normalize sum to 1
    p_ = tf.divide(y_true, tf.tile(tf.expand_dims(tf.reduce_sum(y_true, axis=1), 1), [1,p_shape[1]]))
    q_ = tf.divide(y_pred, tf.tile(tf.expand_dims(tf.reduce_sum(y_pred, axis=1), 1), [1,p_shape[1]]))
    
    return tf.reduce_sum(tf.multiply(p_, tf.math.log(tf.divide(p_, q_))), axis=1)

def total_loss (y_true, y_pred):

    px_loss = pixel_loss(y_true, y_pred)

    ctx_loss = contextual_loss(y_true, y_pred)
    
    return (0.2 * px_loss) + (0.8 * ctx_loss)

# %%
img_shape = (256, 256, 3)

d_model = discriminator(img_shape)

g_model = generator(img_shape)

gan_model = GAN(g_model, d_model, img_shape)

# %%
d_model.summary()
# Out:
# Model: "discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate (Concatenate)      (None, 256, 256, 6)  0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 64  6208        ['concatenate[0][0]']
#                                 )
#
#  leaky_re_lu (LeakyReLU)        (None, 128, 128, 64  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 512)  524800      ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 64, 64, 512)  0           ['conv2d_3[0][0]']
#
#  instance_normalization_2 (Inst  (None, 64, 64, 512)  2          ['leaky_re_lu_3[0][0]']
#  anceNormalization)
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 1)    8193        ['instance_normalization_2[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 539,203
# Trainable params: 0
# Non-trainable params: 539,203
# __________________________________________________________________________________________________

# %%
g_model.summary()
# Out:
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 64  3136        ['input_3[0][0]']
#                                 )
#
#  leaky_re_lu_4 (LeakyReLU)      (None, 128, 128, 64  0           ['conv2d_5[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 128)  131200      ['leaky_re_lu_4[0][0]']
#
#  leaky_re_lu_5 (LeakyReLU)      (None, 64, 64, 128)  0           ['conv2d_6[0][0]']
#
#  instance_normalization_3 (Inst  (None, 64, 64, 128)  2          ['leaky_re_lu_5[0][0]']
#  anceNormalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  524544      ['instance_normalization_3[0][0]'
#                                                                  ]
#
#  leaky_re_lu_6 (LeakyReLU)      (None, 32, 32, 256)  0           ['conv2d_7[0][0]']
#
#  instance_normalization_4 (Inst  (None, 32, 32, 256)  2          ['leaky_re_lu_6[0][0]']
#  anceNormalization)
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  2097664     ['instance_normalization_4[0][0]'
#                                                                  ]
#
#  leaky_re_lu_7 (LeakyReLU)      (None, 16, 16, 512)  0           ['conv2d_8[0][0]']
#
#  instance_normalization_5 (Inst  (None, 16, 16, 512)  2          ['leaky_re_lu_7[0][0]']
#  anceNormalization)
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    4194816     ['instance_normalization_5[0][0]'
#                                                                  ]
#
#  leaky_re_lu_8 (LeakyReLU)      (None, 8, 8, 512)    0           ['conv2d_9[0][0]']
#
#  instance_normalization_6 (Inst  (None, 8, 8, 512)   2           ['leaky_re_lu_8[0][0]']
#  anceNormalization)
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 512)    4194816     ['instance_normalization_6[0][0]'
#                                                                  ]
#
#  leaky_re_lu_9 (LeakyReLU)      (None, 4, 4, 512)    0           ['conv2d_10[0][0]']
#
#  instance_normalization_7 (Inst  (None, 4, 4, 512)   2           ['leaky_re_lu_9[0][0]']
#  anceNormalization)
#
#  conv2d_11 (Conv2D)             (None, 2, 2, 512)    4194816     ['instance_normalization_7[0][0]'
#                                                                  ]
#
#  leaky_re_lu_10 (LeakyReLU)     (None, 2, 2, 512)    0           ['conv2d_11[0][0]']
#
#  instance_normalization_8 (Inst  (None, 2, 2, 512)   2           ['leaky_re_lu_10[0][0]']
#  anceNormalization)
#
#  up_sampling2d (UpSampling2D)   (None, 4, 4, 512)    0           ['instance_normalization_8[0][0]'
#                                                                  ]
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 512)    4194816     ['up_sampling2d[0][0]']
#
#  dropout (Dropout)              (None, 4, 4, 512)    0           ['conv2d_12[0][0]']
#
#  instance_normalization_9 (Inst  (None, 4, 4, 512)   2           ['dropout[0][0]']
#  anceNormalization)
#
#  concatenate_1 (Concatenate)    (None, 4, 4, 1024)   0           ['instance_normalization_9[0][0]'
#                                                                  , 'instance_normalization_7[0][0]
#                                                                  ']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 8, 8, 1024)  0           ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 8, 8, 512)    8389120     ['up_sampling2d_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 8, 8, 512)    0           ['conv2d_13[0][0]']
#
#  instance_normalization_10 (Ins  (None, 8, 8, 512)   2           ['dropout_1[0][0]']
#  tanceNormalization)
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 1024)   0           ['instance_normalization_10[0][0]
#                                                                  ',
#                                                                   'instance_normalization_6[0][0]'
#                                                                  ]
#
#  up_sampling2d_2 (UpSampling2D)  (None, 16, 16, 1024  0          ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 512)  8389120     ['up_sampling2d_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 512)  0           ['conv2d_14[0][0]']
#
#  instance_normalization_11 (Ins  (None, 16, 16, 512)  2          ['dropout_2[0][0]']
#  tanceNormalization)
#
#  concatenate_3 (Concatenate)    (None, 16, 16, 1024  0           ['instance_normalization_11[0][0]
#                                 )                                ',
#                                                                   'instance_normalization_5[0][0]'
#                                                                  ]
#
#  up_sampling2d_3 (UpSampling2D)  (None, 32, 32, 1024  0          ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  4194560     ['up_sampling2d_3[0][0]']
#
#  instance_normalization_12 (Ins  (None, 32, 32, 256)  2          ['conv2d_15[0][0]']
#  tanceNormalization)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 512)  0           ['instance_normalization_12[0][0]
#                                                                  ',
#                                                                   'instance_normalization_4[0][0]'
#                                                                  ]
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 512)  0          ['concatenate_4[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 128)  1048704     ['up_sampling2d_4[0][0]']
#
#  instance_normalization_13 (Ins  (None, 64, 64, 128)  2          ['conv2d_16[0][0]']
#  tanceNormalization)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 256)  0           ['instance_normalization_13[0][0]
#                                                                  ',
#                                                                   'instance_normalization_3[0][0]'
#                                                                  ]
#
#  up_sampling2d_5 (UpSampling2D)  (None, 128, 128, 25  0          ['concatenate_5[0][0]']
#                                 6)
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  262208      ['up_sampling2d_5[0][0]']
#                                 )
#
#  instance_normalization_14 (Ins  (None, 128, 128, 64  2          ['conv2d_17[0][0]']
#  tanceNormalization)            )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 12  0           ['instance_normalization_14[0][0]
#                                 8)                               ',
#                                                                   'leaky_re_lu_4[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 12  0          ['concatenate_6[0][0]']
#                                 8)
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 3)  6147        ['up_sampling2d_6[0][0]']
#
# ==================================================================================================
# Total params: 41,825,691
# Trainable params: 41,825,691
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
gan_model.summary()
# Out:
# Model: "GAN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  generator (Functional)         (None, 256, 256, 3)  41825691    ['input_4[0][0]']
#
#  discriminator (Functional)     (None, 64, 64, 1)    539203      ['input_4[0][0]',
#                                                                   'generator[0][0]']
#
# ==================================================================================================
# Total params: 42,364,894
# Trainable params: 41,825,691
# Non-trainable params: 539,203
# __________________________________________________________________________________________________

# %%
def train(d_model, g_model, gan_model, data,  n_epochs, n_batch=16):
    # determine the output square shape of the discriminator
    n_patch = d_model.output_shape[1]
    
    blue_photo = data[0]
    blue_sketch = data[1]
    
    for i in range(n_epochs):
        print(' ========== Epoch', i+1, '========== ')
        
        blue_photo, blue_sketch = shuffle(blue_photo, blue_sketch)
        
        
        for j in range(int(len(blue_photo)/n_batch)):
            
            start = int(j*n_batch) 
            end = int(min(len(blue_photo), (j*n_batch)+n_batch))
            

            dataset = [blue_photo[start:end], blue_sketch[start:end]]

            # select a batch of real samples
            [X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
            
            # generate a batch of fake samples
            X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
            
            # update discriminator for real samples
            d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
            
            # update discriminator for generated samples
            d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
            
            d_loss = 0.5 * np.add(d_loss1, d_loss2)
            
            # update the generator
            g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
            
            # summarize performance
           # print('Batch : %d, D Loss : %.3f | G Loss : %.3f' % (j+1, d_loss, g_loss))
        
        # summarize model performance
#         if (i+1) % 10 == 0:
        summarize_performance(i, g_model, d_model, dataset)

# %%
opt = Adam(lr=2e-4, beta_1=0.5)

d_model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
gan_model.compile(loss=['binary_crossentropy', total_loss], optimizer=opt, loss_weights=[1,100])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
train(d_model, g_model, gan_model, [train_sketch_image, train_image],  n_epochs = 200, n_batch=16)
# Out:
#  ========== Epoch 1 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 2 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# >Saved:  g_model & d_model
#  ========== Epoch 3 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 4 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 5 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 6 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 7 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 8 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 9 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 10 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 11 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 12 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 13 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 14 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 15 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 16 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 17 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 18 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 19 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 20 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 21 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 22 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 23 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 24 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 25 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 26 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 27 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 28 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 29 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 30 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 31 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 32 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 33 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 34 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 35 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 36 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 37 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 38 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 39 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 40 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 41 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 42 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 43 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 44 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 45 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 46 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 47 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 48 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 49 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 50 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 51 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 52 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 53 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 54 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 55 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 56 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 57 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 58 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 59 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 60 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 61 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 62 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 63 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 64 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 65 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 66 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 67 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 68 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 69 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 70 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 71 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 72 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 73 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 74 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 75 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 76 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 77 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 78 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 79 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 80 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 81 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 82 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 83 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 84 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 85 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 86 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 87 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 88 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 89 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 90 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 91 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 92 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 93 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 94 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 95 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 96 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 97 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 98 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 99 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 100 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 101 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 102 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 103 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 104 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 105 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 106 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 107 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 108 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 109 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 110 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 111 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 112 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 113 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 114 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 115 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 116 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 117 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 118 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 119 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 120 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 121 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 122 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 123 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 124 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 125 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 126 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 127 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 128 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 129 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 130 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 131 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 132 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 133 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 134 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 135 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 136 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 137 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 138 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 139 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 140 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 141 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 142 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 143 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 144 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 145 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 146 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 147 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 148 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 149 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 150 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 151 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 152 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 153 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 154 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 155 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 156 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 157 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 158 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 159 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 160 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 161 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 162 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 163 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 164 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 165 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 166 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 167 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 168 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 169 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 170 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 171 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 172 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 173 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 174 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 175 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 176 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 177 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 178 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 179 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 180 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 181 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 182 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 183 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 184 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 185 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 186 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 187 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 188 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 189 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 190 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 191 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 192 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 193 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 194 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 195 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 196 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 197 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 198 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 199 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model
#  ========== Epoch 200 ==========
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >Saved:  g_model & d_model

# %% [markdown]
# # TESTING

# %%
from keras.models import load_model

# %%
g_model = load_model('g_model.h5',custom_objects={'InstanceNormalization':InstanceNormalization})

# load and resize the image
img = test_sketch_image[0]
target = test_image[0]
#img = img_to_array(img)
#norm_img = (img.copy() - 127.5) / 127.5

g_img = g_model.predict(np.expand_dims(img, 0))[0]
g_img = g_img * 127.5 + 127.5

#img = cv2.resize(img, (200, 250))
g_img = cv2.resize(g_img, (200, 250))

f = plt.figure(num=None, figsize=(12, 6), dpi=80)
#ax1 = f.add_subplot(1,3, 1)
#plt.imshow(img.astype('uint8'))
ax2 = f.add_subplot(1,3, 2)
plt.imshow(g_img.astype('uint8'))
#ax3 = f.add_subplot(1,3, 3)
#plt.imshow(target.astype('uint8'))
#ax1.set_title('Sketch')
#ax2.set_title('Generated Image')
#ax3.set_title('Target Image')

plt.show(block=True)



plot_images(test_sketch_image[0],test_image[0])
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
